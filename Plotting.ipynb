# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mpl_toolkits import mplot3d #for 3d plot
import seaborn as sns

# %%
figgr = plt.figure(figsize=(11,7))
gdr=np.loadtxt('gr.dat')
gdr10=np.loadtxt('gr_10.dat')
gdr5=np.loadtxt('gr_5.dat')
gdr40=np.loadtxt('gr_40.dat')
x1, y1, x10, y10, x5, y5, x40, y40= gdr[:,0], gdr[:,1], gdr10[:,0], gdr10[:,1], gdr5[:,0], gdr5[:,1], gdr40[:,0], gdr40[:,1]
#plt.plotfile('gr.dat', delimiter=' ', cols=(0, 1), names=('r/$\sigma$', 'gr(r/$\sigma$)'), marker='x')
plt.plot(x1, y1+4, marker='.', label="T= 80 °C")
plt.plot(x40, y40+3, marker='.', label="T=40 °C")
plt.plot(x5, y5+2, marker='.', label="T=20 °C")
plt.plot(x10, y10+1, marker='.', label="T=10 °C")
plt.xlabel("$r/\sigma$")
plt.ylabel("g($r/\sigma$)")
plt.legend()
plt.show()

# %%
figgr = plt.figure(figsize=(11,7))
gdr10=np.loadtxt('energy_10.dat')
gdr5=np.loadtxt('energy_5.dat')
gdr40=np.loadtxt('energy_40.dat')
x10, y10, x5, y5, x40, y40= gdr10[:,0], gdr10[:,1], gdr5[:,0], gdr5[:,1], gdr40[:,0], gdr40[:,1]
#plt.plotfile('gr.dat', delimiter=' ', cols=(0, 1), names=('r/$\sigma$', 'gr(r/$\sigma$)'), marker='x')
plt.plot(x40, y40, marker='.', label="T=40 °C")
plt.plot(x5, y5, marker='.', label="T=20 °C")
plt.plot(x10, y10, marker='.', label="T=10 °C")
plt.xlabel("$r/\sigma$")
plt.ylabel("energy")
plt.legend()
plt.show()

# %%
figgr = plt.figure(figsize=(11,7))
gr=np.loadtxt('gr_10.dat')
gr45=np.loadtxt('gr_phi45.dat')
x, y, x45, y45= gr[:,0], gr[:,1], gr45[:,0], gr45[:,1]
#plt.plotfile('gr.dat', delimiter=' ', cols=(0, 1), names=('r/$\sigma$', 'gr(r/$\sigma$)'), marker='x')
plt.plot(x, y, marker='.', label="phi=0.36")
plt.plot(x45, y45+1, marker='.', label="phi=0.45")
plt.xlabel("$r/\sigma$")
plt.ylabel("g(r/$\sigma$)")
plt.legend()
plt.show()

# %%
#fig = plt.figure(figsize=(11,7))
ax = plt.axes(projection='3d')
icd=np.loadtxt('iniconf.dat')
xi = icd[:,0]
yi = icd[:,1]
zi = icd[:,2]

ax.scatter(xi,yi,zi,
                #c=zi,
                cmap='viridis',
                marker='x')
ax.set_title('water configuration \n')
#ax.view_init(30, 5)

plt.show()
